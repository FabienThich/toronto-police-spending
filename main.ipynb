# %%
import pandas as pd

df = pd.read_csv('data/TPS Budget 2025.csv')
df.tail()
# Out:
#        _id  Fiscal_Year      Budget_Type    Organizational_Entity  \
# 7684  7685         2025  Proposed Budget  3 - Parking Enforcement
# 7685  7686         2025  Proposed Budget  3 - Parking Enforcement
# 7686  7687         2025  Proposed Budget  3 - Parking Enforcement
# 7687  7688         2025  Proposed Budget  3 - Parking Enforcement
# 7688  7689         2025  Proposed Budget  3 - Parking Enforcement
#
#              Command_Name                   Pillar_Name  \
# 7684  Parking Enforcement  Parking Enforcement (Pillar)
# 7685  Parking Enforcement  Parking Enforcement (Pillar)
# 7686  Parking Enforcement  Parking Enforcement (Pillar)
# 7687  Parking Enforcement  Parking Enforcement (Pillar)
# 7688  Parking Enforcement  Parking Enforcement (Pillar)
#
#                  District_Name            Unit_Name Feature_Category  \
# 7684  Parking Enforcement Unit  Parking Enforcement       6-Services
# 7685  Parking Enforcement Unit  Parking Enforcement       6-Services
# ...

# %%
df = pd.read_csv('data/TPS Budget 2024.csv')
df.tail()
# Out:
#        _id  Fiscal_Year      Budget_Type  Organization_Entity  \
# 7684  7685         2024  Approved Budget                  NaN
# 7685  7686         2024  Approved Budget                  NaN
# 7686  7687         2024  Approved Budget                  NaN
# 7687  7688         2024  Approved Budget                  NaN
# 7688  7689         2024  Approved Budget                  NaN
#
#              Command_Name                   Pillar_Name  \
# 7684  Parking Enforcement  Parking Enforcement (Pillar)
# 7685  Parking Enforcement  Parking Enforcement (Pillar)
# 7686  Parking Enforcement  Parking Enforcement (Pillar)
# 7687  Parking Enforcement  Parking Enforcement (Pillar)
# 7688  Parking Enforcement  Parking Enforcement (Pillar)
#
#                  District_Name            Unit_Name Feature_Category  \
# 7684  Parking Enforcement Unit  Parking Enforcement       6-Services
# 7685  Parking Enforcement Unit  Parking Enforcement       6-Services
# ...
